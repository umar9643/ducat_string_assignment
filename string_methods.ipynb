# %% [markdown]
# # STRING IN PYTHON

# %% [markdown]
# ## What is a str in Python?

# %% [markdown]
# In Python, str (short for string) is a data type used to store textual data.
#
# A string is a sequence of characters enclosed in single quotes ' ', double quotes " ", or triple quotes ''' ''' / """ """
#
# A string (str) is an ordered collection of characters used to represent text.
#
# It can contain letters, numbers, symbols, or even spaces.

# %% [markdown]
# ## str methods

# %% [markdown]
# String methods (str methods) are built-in functions in Python that help you work with text (strings) easily — like checking, modifying, searching, or formatting text.

# %%
string="My name is UMAR ALAM i am learing Data Science"
string.capitalize()
#capitalize() is a Python string (str) method used to make the first character uppercase and all remaining characters lowercase.
# Out:
# 'My name is umar alam i am learing data science'

# %% [markdown]
# ## str.casefold

# %% [markdown]
# It converts a string to lowercase in a way suitable for comparing text, even for international characters.

# %%
string="My name is UMAR ALAM i am learing Data Science"
string.casefold()#same as lowecase
# Out:
# 'my name is umar alam i am learing data science'

# %% [markdown]
# ## str.center

# %% [markdown]
# center() is a Python string (str) method used to place a string in the center of a given width by adding padding (usually spaces) on both sides.
#
# syntax : string.center(width, fillchar)

# %% [markdown]
# Parameters:
#
# width → total length of final string
#
# fillchar (optional) → character used for padding (default = space)

# %%
string="umar"

# %%
string.center(6)
# Out:
# ' umar '

# %%
string.center(8,"*")
# Out:
# '**umar**'

# %% [markdown]
# ## str.count

# %% [markdown]
# count() is a Python string (str) method used to count how many times a substring appears inside a string.
#
#  syntax: string.count(substring, start, end)
#
# Parameters:
# substring → text you want to count (required)
# start → starting index (optional)
# end → ending index (optional)

# %%
string="My name is UMAR ALAM i am learing Data Science"

string.count("A")
# Out:
# 3

# %%
text = "hello hello"
print(text.count("hello"))

# %%
text = "banana"
print(text.count("a", 2, 6))
# Out:
# 2

# %% [markdown]
# ## str.encode

# %% [markdown]
# encode() is a Python string (str) method used to convert a string into bytes using a specific character encoding (like UTF-8).
#
# syntax:  string.encode(encoding="utf-8", errors="strict")
#
# Parameters
# encoding → format used for conversion (default: "utf-8")
# errors → what to do if encoding fails (strict, ignore, replace)

# %%
text = "alam"
result = text.encode()

print(result)
# Out:
# b'alam'

# %%
text = "café"
print(text.encode("utf-8"))
# Out:
# b'caf\xc3\xa9'

# %% [markdown]
# ## str.endswith

# %% [markdown]
# endswith() is a Python string (str) method used to check whether a string ends with a specified suffix.
#
# syntax: string.endswith(suffix, start, end)
#
# Parameters:
# suffix → character or substring to check at the end (required)
# start → starting index for checking (optional)
# end → ending index for checking (optional)
#
# Returns:
#
# True  → if the string ends with the given suffix
# False → otherwise

# %%
text = "hello world"
print(text.endswith("hello", 0, 5))
# Out:
# True

# %%
string="My name is UMAR ALAM i am learing Data Science"
print(string.endswith("Science"))
print(string.endswith("science"))S
# Out:
# True
# False

# %% [markdown]
# ## str.expandtabs

# %% [markdown]
# expandtabs() is a Python string (str) method used to replace tab characters (\t) in a string with spaces.
#
# syntax: string.expandtabs(tabsize)
#
# Parameters:
# tabsize → number of spaces to replace each tab character with (optional, default = 8)
# Returns:
#
# A new string where all tab (\t) characters are replaced by spaces.

# %%
text = "Hello\tWorld"
print(text)
print(text.expandtabs(4))
#(tab replaced with 4 spaces)
# Out:
# Hello	World
# Hello   World

# %%
text = "Hello\t\tWorld"
print(text)
# Out:
# Hello		World

# %% [markdown]
# ## str.find

# %% [markdown]
# str.find() ek string method hai jo kisi substring ko search karta hai aur uska index (position) return karta hai.

# %% [markdown]
# Syntax:
# string.find(substring, start, end)
#
# substring → kya search karna hai
# start (optional) → kaha se search start kare
# end (optional) → kaha tak search kare

# %%
text = "hello world"
print(text.find("world"))
# Out:
# 6

# %%
string="My name is UMAR ALAM i am learing Data Science"
string.find("n")
# Out:
# 3

# %%
text = "banana"
print(text.find("a", 2, 5))

#Index 2 se 5 ke beech search karega.
# Out:
# 3

# %% [markdown]
# ## str.index

# %% [markdown]
# str.index() ek string method hai jo kisi substring ka first occurrence ka index (position) return karta hai.
# Agar substring nahi mila, toh ye error (ValueError) throw karta hai.

# %%
text = "hello world"
print(text.index("world"))
# Out:
# 6

# %%
text = "hello world"
print(text.index("worlds"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 text = "hello world"
# ----> 2 print(text.index("worlds"))
#
# ValueError: substring not found

# %% [markdown]
# ## str.format

# %% [markdown]
# str.format() ek string method hai jo string ke andar placeholders {} ki jagah par values insert karne ke liye use hota hai.
# Isse hum string formatting karte hain — yani dynamic values ko string me daalte hain.

# %% [markdown]
# Syntax:
# string.format(value1, value2, ...)

# %% [markdown]
# Ya agar index use karna ho:
# string.format(arg0, arg1, ...)

# %%
name = "Umar"
age = 22

text = "My name is {} and I am {} years old.".format(name, age)
print(text)
# Out:
# My name is Umar and I am 22 years old.

# %%
text = "I love {1} and {0}".format("Python", "ML")
print(text)
# Out:
# I love ML and Python

# %% [markdown]
# ## str.format_map

# %% [markdown]
# str.format_map() ek string method hai jo dictionary (mapping) ke through string ke placeholders {} ko replace karta hai.
# Ye str.format() jaisa hi hai, lekin direct dictionary ko accept karta hai — bina ** unpacking ke.

# %%
data = {"name": "Umar", "age": 22}

text = "My name is {name} and I am {age} years old.".format_map(data)
print(text)
# Out:
# My name is Umar and I am 22 years old.

# %% [markdown]
# ## str.isalnum

# %% [markdown]
# isalnum() is a built-in string method in Python that checks whether a string contains only alphanumeric characters—that is, only letters (A–Z, a–z) and digits (0–9), with no spaces, symbols, or punctuation.
#
# It returns True if all characters in the string are alphanumeric and the string is not empty; otherwise, it returns False.

# %%
print("Python123".isalnum())   # True
print("Python 123".isalnum())  # False (space)
print("123!".isalnum())        # False (symbol)
print("".isalnum())            # False (empty string)
# Out:
# True
# False
# False
# False

# %% [markdown]
# ## str.isdigit

# %% [markdown]
# isdigit() Checks if the string contains only numeric digits (0–9). No letters, spaces, or symbols.

# %%
print("123".isdigit())       # ✅ True (all digits)
print("000456".isdigit())    # ✅ True (all digits, leading zeros OK)
print("12a3".isdigit())      # ❌ False (contains a letter)
print("123.45".isdigit())    # ❌ False (dot is not a digit)
print("".isdigit())          # ❌ False (empty string)
print("12 34".isdigit())     # ❌ False (space not allowed)
# Out:
# True
# True
# False
# False
# False
# False

# %% [markdown]
# ## str.isalpha

# %% [markdown]
# isalpha() is a built-in string method in Python that checks if a string contains only alphabetic characters (A–Z or a–z) and no numbers, spaces, or special characters.
# It returns True if all characters in the string are alphabets and the string is not empty; otherwise, it returns False.

# %%
print("Python".isalpha())     # ✅ True (only letters)
print("Python123".isalpha())  # ❌ False (has numbers)
print("Python!".isalpha())    # ❌ False (has symbol)
print("Python Code".isalpha())# ❌ False (has space)
print("".isalpha())           # ❌ False (empty string)
# Out:
# True
# False
# False
# False
# False

# %% [markdown]
# ## str.islower

# %% [markdown]
# islower() is a string method in Python that checks if all the alphabetic characters in the string are in lowercase (i.e., from 'a' to 'z').
#
# It returns True if the string contains at least one letter, and all letters are lowercase.
#
# Non-letter characters such as numbers, spaces, or symbols are ignored during the check. If the string has no alphabetic characters or contains even one uppercase letter, it returns False.

# %%
print("hello".islower())       # ✅ True (all letters are lowercase)
print("hello123".islower())    # ✅ True (letters are lowercase, digits are ignored)
print("hello!".islower())      # ✅ True (symbols are ignored)
print("Hello".islower())       # ❌ False (contains uppercase 'H')
print("123".islower())         # ❌ False (no letters)
print("".islower())            # ❌ False (empty string)
# Out:
# True
# True
# True
# False
# False
# False

# %% [markdown]
# ## str.isupper

# %% [markdown]
# isupper() is a built-in string method in Python.
# It returns True if all the alphabetic characters in the string are uppercase letters (A–Z) and there is at least one letter. Otherwise, it returns False.

# %%
print("HELLO".isupper())       # True → All letters are uppercase
print("HELLO123".isupper())    # True → Letters are uppercase, digits are ignored
print("HELLO!".isupper())      # True → Symbols are ignored
print("Hello".isupper())       # False → Contains lowercase 'e'
print("123".isupper())         # False → No letters at all
print("".isupper())            # False → Empty string
# Out:
# True
# True
# True
# False
# False
# False

# %% [markdown]
# ## str.istitle

# %% [markdown]
# The istitle() method in Python is used to check whether a string is in title case. A string is said to be in title case if each word in the string:
#
# Starts with an uppercase letter (A-Z), and
# The rest of the characters in each word are lowercase letters (a-z).

# %%
# Only letters, proper title case
print("This Is Python".istitle())  # ✅ True

# Lowercase word
print("This is Python".istitle())  # ❌ False ("is" is not capitalized)

# All uppercase
print("THIS IS PYTHON".istitle())  # ❌ False

# Mixed with numbers and punctuation
print("Hello World 2025!".istitle())  # ✅ True

# Number at the start of word
print("Hello 123World".istitle())    # ❌ False ("123World" is not a title word)

# Symbol in between
print("Welcome To #Python!".istitle())  # ✅ True

# Starts with a lowercase letter after a space
print("Python is Great!".istitle())     # ❌ False

# Title case with punctuation
print("The Cat's Meow.".istitle())      # ✅ True

# Word starts with a symbol
print("Hello @World".istitle())         # ❌ False ("@World" doesn't start with a letter)
# Out:
# True
# False
# False
# True
# True
# True
# False
# False
# True

# %% [markdown]
# ## str.isidentifier

# %% [markdown]
# str.isidentifier() check karta hai ki koi string valid Python identifier (variable name) hai ya nahi.
#
# Ye True return karta hai agar string:
# Letter ya _ (underscore) se start hoti ho
# Sirf letters, digits, aur _ contain karti ho
# Python keyword na ho (⚠️ note niche dekho)

# %%
name="age"
print(name.isidentifier())
# Out:
# True

# %%
name = "2variable1"
print(name.isidentifier())
# Out:
# False

# %% [markdown]
# ## str.join

# %% [markdown]
# str.join() ek string method hai jo iterable (list, tuple, etc.) ke elements ko ek string me combine karta hai — aur beech me jo string call kar rahi hoti hai, wo separator ka kaam karti hai.
#
# Simple words me:
# Separator + join = ek final string

# %% [markdown]
# syntax:  separator.join(iterable)

# %%
words = ["Hello", "Umar", "ML"]
result = " ".join(words)
print(result)
# Out:
# Hello Umar ML

# %%
numbers = ["1", "2", "3"]
print("-".join(numbers))
# Out:
# 1-2-3

# %% [markdown]
# ## str.lstrip

# %% [markdown]
# str.lstrip() string ke left side (starting side) se unwanted characters ya spaces remove karta hai.
# 👉 Default me ye leading spaces remove karta hai.

# %%
text = "   Umar"
print(text.lstrip())
# Out:
# Umar

# %%
text = "###*Hello"
print(text.lstrip("#"))
# Out:
# *Hello

# %% [markdown]
# ## str.rstrip

# %% [markdown]
# str.rstrip() string ke right side (ending side) se unwanted characters ya spaces remove karta hai.
# 👉 Default me ye ending spaces remove karta hai.

# %%
text = "Hello###"
print(text.rstrip("#"))
# Out:
# Hello

# %%
text = "Hellobbaa"
print(text.rstrip("ab"))
# e "ab" ko ek word ki tarah remove nahi karta.Ye right se jitne bhi a ya b milte hain, unhe remove karta rehta hai.
# Out:
# Hello

# %% [markdown]
# ## str.strip

# %% [markdown]
# str.strip() string ke dono sides (left + right) se unwanted characters ya spaces remove karta hai.

# %% [markdown]
# Syntax:
# string.strip(chars)
#
# chars (optional) → kaunse characters remove karne hain
# Agar chars nahi doge → sirf spaces remove karega

# %%
text = "   Umar   "
print(text.strip())
# Out:
# Umar

# %%
text="hi my name ###is umar           i am a data analyst*****  ###          "
print(text)
clean=text.strip(" *")
print(clean)
print(text.strip(" #*"))
# Out:
# hi my name ###is umar           i am a data analyst*****  ###
# hi my name ###is umar           i am a data analyst*****  ###
# hi my name ###is umar           i am a data analyst

# %% [markdown]
# ## str.zfill

# %% [markdown]
# str.zfill() string ke left side me zeros (0) add karta hai, jab tak string ki total length specified width ke barabar na ho jaye.
# 👉 Mostly numbers ko fixed length format me dikhane ke liye use hota hai.

# %% [markdown]
# Syntax:
# string.zfill(width)
#
# width → total length kitni chahiye
# Agar string already usse badi hai → kuch change nahi hoga

# %%
name="44"
print(name.zfill(5))
# Out:
# 00044

# %%
name="44"
print(name.zfill(18))
# Out:
# 000000000000000044

# %%
name="4435454"
print(name.zfill(5))
#nothings happen when the len is already big then the lenght we arre giving
# Out:
# 4435454

# %% [markdown]
# ## str.upper

# %% [markdown]
# Saare characters ko UPPERCASE me convert karta hai.

# %%
goal="my goal is to be a good DATA scientist"
print(goal.upper())
# Out:
# MY GOAL IS TO BE A GOOD DATA SCIENTIST

# %% [markdown]
# ## str.lower

# %%
goal="MY GOAL IS TO BE A GOOD DATA SCIENTIST"
print(goal.lower())
# Out:
# my goal is to be a good data scientist

# %% [markdown]
# ## str.title

# %% [markdown]
# makes  the ist letter of each word capital

# %%
goal="my goal is to be a good DATA scientist"
print(goal.title())
# Out:
# My Goal Is To Be A Good Data Scientist

# %% [markdown]
# ## str.capitalize

# %% [markdown]
# Sirf first character of whole string capital karta hai.

# %%
goal="my goal is to be a good DATA scientist"
print(goal.capitalize())
# Out:
# My goal is to be a good data scientist

# %% [markdown]
# ## str.swapcase

# %% [markdown]
# Upper ko lower aur lower ko upper me convert karta hai.

# %%
goal="My GOAL is to be a good DATA scientist"
print(goal.swapcase())
# Out:
# mY goal IS TO BE A GOOD data SCIENTIST

# %% [markdown]
# ## str.split

# %% [markdown]
# str.split() string ko parts (list of substrings) me tod deta hai, kisi separator ke basis par.
# 👉 Output hamesha list hota hai.

# %% [markdown]
# Syntax
# string.split(separator, maxsplit)
# separator (optional) → kis basis par todna hai
# maxsplit (optional) → maximum kitni baar split karna hai

# %%
text = "hi my name is umar"
print(text.split())
#default split on the basis of spaces
# Out:
# ['hi', 'my', 'name', 'is', 'umar']

# %%
text = "apple,banana,mango"
print(text.split(","))
#spliting on the basis of ","
# Out:
# ['apple', 'banana', 'mango']

# %%
text = "one two three four"
print(text.split(" ", 2))
#use of maxspluit
# Out:
# ['one', 'two', 'three four']

# %% [markdown]
# ## str.rsplit

# %% [markdown]
# rsplit() string ko right side se split karta hai.
#
# 👉 Default behavior split() jaisa hi hota hai.
# Difference tab dikhta hai jab maxsplit use karte ho.

# %%
text = "one two three four"
print(text.rsplit(" ", 2))
# we can see the the split happening form the right
# Out:
# ['one two', 'three', 'four']

# %% [markdown]
# ## str.splitlines

# %% [markdown]
# splitlines() string ko newline (\n) ke basis par split karta hai.
#
# Syntax:
# string.splitlines(keepends=False)
# keepends=True doge to newline character bhi preserve karega

# %%
text = "Hello\nUmar\nData Analyst"
print(text)
print(text.splitlines())
# Out:
# Hello
# Umar
# Data Analyst
# ['Hello', 'Umar', 'Data Analyst']

# %%
text = "Hello\nUmar\nData"
print(text.splitlines(True))
# Out:
# ['Hello\n', 'Umar\n', 'Data']

# %% [markdown]
# ## str.replace

# %% [markdown]
# str.replace() string me kisi substring ko dusre substring se replace karta hai.
# Syntax
# string.replace(old, new, count)
#
# old → jo replace karna ha
# new → jis se replace karna hai
# count (optional) → kitni baar replace karna hai

# %%
text = "hi umar"
print(text.replace("umar", "ali"))
# Out:
# hi ali

# %%
text = "apple apple apple"
print(text.replace("apple", "mango"))
#multiple accurance
# Out:
# mango mango mango

# %%
text = "apple apple apple"
print(text.replace("apple", "mango", 2))
#only 2 occurance replaced
# Out:
# mango mango apple
